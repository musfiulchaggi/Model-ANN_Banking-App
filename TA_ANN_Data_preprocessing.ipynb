# %%
import pandas as pd
import numpy as np

# %%
# Data nasabah
data = {
    'CreditScore': [],
    'Age_category': [],
    'Tenure': [],
    'NumOfProducts': [],
    'New_Estimated_Salary': [],
    'Gender_Female': [],
    'Gender_Male': [],
    'Prediction' : [],
    'Confident' : []
}

# Membuat DataFrame dari data nasabah
df = pd.DataFrame(data)

# Menampilkan DataFrame
print(df)

# Menyimpan DataFrame ke dalam file CSV
df.to_csv('HistReqsApi.csv', index=False)
# Out:
# Empty DataFrame
# Columns: [CreditScore, Age_category, Tenure, NumOfProducts, New_Estimated_Salary, Gender_Female, Gender_Male, Prediction, Confident]
# Index: []

# %%
pd.read_csv('HistReqsApi.csv')
# Out:
# Empty DataFrame
# Columns: [CreditScore, Age_category, Tenure, NumOfProducts, New_Estimated_Salary, Gender_Female, Gender_Male, Prediction, Confident]
# Index: []

# %%
df = pd.read_csv('X_train.csv')
df
# Out:
#       CreditScore  Age  Tenure  NumOfProducts  New_Estimated_Salary  \
# 0             534   52       1              3             10403.541
# 1             670   31       9              1              7625.483
# 2             662   44       8              2             17531.487
# 3             609   37       6              2              2203.072
# 4             631   29       7              2             12587.722
# ...           ...  ...     ...            ...                   ...
# 7120          666   33       2              1              8188.480
# 7121          745   36       9              1              1960.518
# 7122          750   35       3              1             19152.050
# 7123          549   38       8              1             15744.275
# 7124          557   42       4              2              8664.238
#
#       Gender_Female  Gender_Male
# 0                 0            1
# 1                 1            0
# 2                 0            1
# ...

# %%
# # menggunakan peraturan di BPR Amira Untuk Menentukan Label Accepted
# def function(row):
#     val = 0
    
#     if row['CreditScore'] > 2 and row['Age_category'] > 1 and row['New_Estimated_Salary'] > 2 and row['Tenure'] > 2:
#         val = 1
#     elif row['CreditScore'] < 2 and row['Age_category'] > 1 and row['New_Estimated_Salary'] > 2:
#         val = 1
#     elif row['Age_category'] == 0 and row['New_Estimated_Salary'] > 2 and row['CreditScore'] > 1:
#         val = 1
#     elif row['New_Estimated_Salary'] == 1 and row['CreditScore'] > 2 and row['Age_category'] > 1:
#         val = 1
#     elif row['Age_category'] == 0 or row['New_Estimated_Salary'] == 1:
#         val = 0
# #     elif row['Age_category'] == 0 or row['New_Estimated_Salary'] == 1:
# #         val = 0

#     return val

# # menggunakan peraturan di BPR Amira Untuk Menentukan Label Accepted
# # def function(row):
# #     val = 0
    
# #     if row['Age_category'] == 0 or row['New_Estimated_Salary'] == 1 or row['CreditScore'] == 1:
# #         val = 0
# #     elif row['CreditScore'] > 2 and row['Age_category'] > 1 and row['New_Estimated_Salary'] > 2 and row['Tenure'] > 2:
# #         val = 1
# #     elif row['CreditScore'] < 2 and row['Age_category'] > 1 and row['New_Estimated_Salary'] > 2:
# #         val = 1
# #     elif row['Age_category'] == 0 and row['New_Estimated_Salary'] > 2 and row['CreditScore'] > 1:
# #         val = 1
# #     elif row['New_Estimated_Salary'] == 1 and row['CreditScore'] > 2 and row['Age_category'] > 1:
# #         val = 1
# # #     elif row['Age_category'] == 0 or row['New_Estimated_Salary'] == 1:
# # #         val = 0

# #     return val

# %%
# df['New_Accepted'] = df.apply( function , axis=1 )

# %%
df = pd.read_csv('Churn_Modelling.csv')

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
df.count()
# Out:
# RowNumber          10000
# CustomerId         10000
# Surname            10000
# CreditScore        10000
# Geography          10000
# Gender             10000
# Age                10000
# Tenure             10000
# Balance            10000
# NumOfProducts      10000
# HasCrCard          10000
# IsActiveMember     10000
# EstimatedSalary    10000
# Exited             10000
# dtype: int64

# %%
df.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %%
df.drop(columns = ['RowNumber','CustomerId','Surname'], inplace= True )

# %%
df.describe()
# Out:
#         CreditScore           Age        Tenure        Balance  NumOfProducts  \
# count  10000.000000  10000.000000  10000.000000   10000.000000   10000.000000
# mean     650.528800     38.921800      5.012800   76485.889288       1.530200
# std       96.653299     10.487806      2.892174   62397.405202       0.581654
# min      350.000000     18.000000      0.000000       0.000000       1.000000
# 25%      584.000000     32.000000      3.000000       0.000000       1.000000
# 50%      652.000000     37.000000      5.000000   97198.540000       1.000000
# 75%      718.000000     44.000000      7.000000  127644.240000       2.000000
# max      850.000000     92.000000     10.000000  250898.090000       4.000000
#
#          HasCrCard  IsActiveMember  EstimatedSalary        Exited
# count  10000.00000    10000.000000     10000.000000  10000.000000
# mean       0.70550        0.515100    100090.239881      0.203700
# std        0.45584        0.499797     57510.492818      0.402769
# ...

# %%
df.drop(columns = ['HasCrCard','IsActiveMember','Balance'], inplace= True )

# %%
df.describe()
# Out:
#         CreditScore           Age        Tenure  NumOfProducts  \
# count  10000.000000  10000.000000  10000.000000   10000.000000
# mean     650.528800     38.921800      5.012800       1.530200
# std       96.653299     10.487806      2.892174       0.581654
# min      350.000000     18.000000      0.000000       1.000000
# 25%      584.000000     32.000000      3.000000       1.000000
# 50%      652.000000     37.000000      5.000000       1.000000
# 75%      718.000000     44.000000      7.000000       2.000000
# max      850.000000     92.000000     10.000000       4.000000
#
#        EstimatedSalary        Exited
# count     10000.000000  10000.000000
# mean     100090.239881      0.203700
# std       57510.492818      0.402769
# min          11.580000      0.000000
# 25%       51002.110000      0.000000
# 50%      100193.915000      0.000000
# 75%      149388.247500      0.000000
# max      199992.480000      1.000000

# %%
import seaborn as sns
#Calculating correlation between each pair of variables
corr_matrix=df.corr()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

#Creating a seaborn heatmap
plt.figure(1, figsize=(10,5))
sns.heatmap(corr_matrix, cmap='BrBG', center=0, annot=True)
# Out:
# <AxesSubplot:>

# %%
df.drop(columns = ['Geography'], inplace= True )

# %%
df
# Out:
#       CreditScore  Gender  Age  Tenure  NumOfProducts  EstimatedSalary  Exited
# 0             619  Female   42       2              1        101348.88       1
# 1             608  Female   41       1              1        112542.58       0
# 2             502  Female   42       8              3        113931.57       1
# 3             699  Female   39       1              2         93826.63       0
# 4             850  Female   43       2              1         79084.10       0
# ...           ...     ...  ...     ...            ...              ...     ...
# 9995          771    Male   39       5              2         96270.64       0
# 9996          516    Male   35      10              1        101699.77       0
# 9997          709  Female   36       7              1         42085.58       1
# 9998          772    Male   42       3              2         92888.52       1
# 9999          792  Female   28       4              1         38190.78       0
#
# ...

# %%
df['Accepted'] = pd.read_csv('label.csv')

# %%
df['Accepted'].value_counts()
# Out:
# 0    6578
# 1    3422
# Name: Accepted, dtype: int64

# %%
# Out:
#       CreditScore  Gender  Age  Tenure  NumOfProducts  EstimatedSalary  \
# 0             619  Female   42       2              1        101348.88
# 1             608  Female   41       1              1        112542.58
# 2             502  Female   42       8              3        113931.57
# 3             699  Female   39       1              2         93826.63
# 4             850  Female   43       2              1         79084.10
# ...           ...     ...  ...     ...            ...              ...
# 9995          771    Male   39       5              2         96270.64
# 9996          516    Male   35      10              1        101699.77
# 9997          709  Female   36       7              1         42085.58
# 9998          772    Male   42       3              2         92888.52
# 9999          792  Female   28       4              1         38190.78
#
#       Exited  Accepted
# 0          1         0
# 1          0         0
# 2          1         0
# ...

# %%
# change estimated salary to ID
df['New_Estimated_Salary'] = df['EstimatedSalary']/10

# %%
# removing outliers
LowerLimit = df['New_Estimated_Salary'].quantile(0.05) # 0.05 is 5%
LowerLimit
# Out:
# 985.1818500000003

# %%
df = df[(df['New_Estimated_Salary'] > LowerLimit)]
df
# Out:
#       CreditScore  Gender  Age  Tenure  NumOfProducts  EstimatedSalary  \
# 0             619  Female   42       2              1        101348.88
# 1             608  Female   41       1              1        112542.58
# 2             502  Female   42       8              3        113931.57
# 3             699  Female   39       1              2         93826.63
# 4             850  Female   43       2              1         79084.10
# ...           ...     ...  ...     ...            ...              ...
# 9995          771    Male   39       5              2         96270.64
# 9996          516    Male   35      10              1        101699.77
# 9997          709  Female   36       7              1         42085.58
# 9998          772    Male   42       3              2         92888.52
# 9999          792  Female   28       4              1         38190.78
#
#       Exited  Accepted  New_Estimated_Salary
# 0          1         0             10134.888
# ...

# %%
df.count()
# Out:
# CreditScore             9500
# Gender                  9500
# Age                     9500
# Tenure                  9500
# NumOfProducts           9500
# Accepted                9500
# New_Estimated_Salary    9500
# dtype: int64

# %%
df.drop(columns=['EstimatedSalary'],inplace=True)
# Out:
# C:\Users\BISMILLAH NAWAITU\AppData\Local\Temp\ipykernel_6616\3340678355.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['EstimatedSalary'],inplace=True)

# %%
df.drop(columns=['Exited'],inplace=True)
# Out:
# C:\Users\BISMILLAH NAWAITU\AppData\Local\Temp\ipykernel_6616\3243205806.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['Exited'],inplace=True)

# %%
df['New_Accepted'] = df.apply( function , axis=1 )

# df['New_Accepted'] = np.where(df['Exited'] == 0,1,0)

# df['New_Accepted'] = df['Exited']

# %%
df['New_Accepted'].value_counts()
# Out:
# 0    6578
# 1    3422
# Name: New_Accepted, dtype: int64

# %%
df.describe()
# Out:
#              Tenure  NumOfProducts        Exited  New_Accepted
# count  10000.000000   10000.000000  10000.000000   10000.00000
# mean       5.012800       1.530200      0.203700       0.34220
# std        2.892174       0.581654      0.402769       0.47447
# min        0.000000       1.000000      0.000000       0.00000
# 25%        3.000000       1.000000      0.000000       0.00000
# 50%        5.000000       1.000000      0.000000       0.00000
# 75%        7.000000       2.000000      0.000000       1.00000
# max       10.000000       4.000000      1.000000       1.00000

# %%
# df.drop_duplicates(inplace=True)
df.to_excel('data_export3.xlsx', index = False, sheet_name='data')

# %%
df.corr()
# Out:
#                       CreditScore       Age    Tenure  NumOfProducts  \
# CreditScore              1.000000 -0.007490  0.003898       0.014578
# Age                     -0.007490  1.000000 -0.011130      -0.028194
# Tenure                   0.003898 -0.011130  1.000000       0.014977
# NumOfProducts            0.014578 -0.028194  0.014977       1.000000
# Accepted                 0.607814 -0.170268  0.002106       0.011776
# New_Estimated_Salary    -0.003420 -0.012053 -0.001799       0.018976
#
#                       Accepted  New_Estimated_Salary
# CreditScore           0.607814             -0.003420
# Age                  -0.170268             -0.012053
# Tenure                0.002106             -0.001799
# NumOfProducts         0.011776              0.018976
# Accepted              1.000000              0.272914
# New_Estimated_Salary  0.272914              1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9500 entries, 0 to 9999
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   CreditScore           9500 non-null   int64
#  1   Gender                9500 non-null   object
#  2   Age                   9500 non-null   int64
#  3   Tenure                9500 non-null   int64
#  4   NumOfProducts         9500 non-null   int64
#  5   Accepted              9500 non-null   int64
#  6   New_Estimated_Salary  9500 non-null   float64
# dtypes: float64(1), int64(5), object(1)
# memory usage: 593.8+ KB

# %%
# one hot encoding use dummies
columns = ['Gender']
dummyData = pd.get_dummies(df[columns])
dummyData
# tambah data use concat
df = pd.concat([df,dummyData],axis=1)
df
# Out:
#       CreditScore  Gender  Age  Tenure  NumOfProducts  Accepted  \
# 0             619  Female   42       2              1         0
# 1             608  Female   41       1              1         0
# 2             502  Female   42       8              3         0
# 3             699  Female   39       1              2         1
# 4             850  Female   43       2              1         1
# ...           ...     ...  ...     ...            ...       ...
# 9995          771    Male   39       5              2         1
# 9996          516    Male   35      10              1         0
# 9997          709  Female   36       7              1         0
# 9998          772    Male   42       3              2         1
# 9999          792  Female   28       4              1         0
#
#       New_Estimated_Salary  Gender_Female  Gender_Male
# 0                10134.888              1            0
# 1                11254.258              1            0
# ...

# %%
df.drop(columns='Gender',inplace=True)

# %%
df
# Out:
#       CreditScore  Age  Tenure  NumOfProducts  Accepted  New_Estimated_Salary  \
# 0             619   42       2              1         0             10134.888
# 1             608   41       1              1         0             11254.258
# 2             502   42       8              3         0             11393.157
# 3             699   39       1              2         1              9382.663
# 4             850   43       2              1         1              7908.410
# ...           ...  ...     ...            ...       ...                   ...
# 9995          771   39       5              2         1              9627.064
# 9996          516   35      10              1         0             10169.977
# 9997          709   36       7              1         0              4208.558
# 9998          772   42       3              2         1              9288.852
# 9999          792   28       4              1         0              3819.078
#
#       Gender_Female  Gender_Male
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9500 entries, 0 to 9999
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   CreditScore           9500 non-null   int64
#  1   Age                   9500 non-null   int64
#  2   Tenure                9500 non-null   int64
#  3   NumOfProducts         9500 non-null   int64
#  4   Accepted              9500 non-null   int64
#  5   New_Estimated_Salary  9500 non-null   float64
#  6   Gender_Female         9500 non-null   uint8
#  7   Gender_Male           9500 non-null   uint8
# dtypes: float64(1), int64(5), uint8(2)
# memory usage: 538.1 KB

# %%
import seaborn as sns
sns.set()

# %%
df.plot.hist(bins=30)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df
# Out:
#       CreditScore  Age  Tenure  NumOfProducts  Accepted  New_Estimated_Salary  \
# 0             619   42       2              1         0             10134.888
# 1             608   41       1              1         0             11254.258
# 2             502   42       8              3         0             11393.157
# 3             699   39       1              2         1              9382.663
# 4             850   43       2              1         1              7908.410
# ...           ...  ...     ...            ...       ...                   ...
# 9995          771   39       5              2         1              9627.064
# 9996          516   35      10              1         0             10169.977
# 9997          709   36       7              1         0              4208.558
# 9998          772   42       3              2         1              9288.852
# 9999          792   28       4              1         0              3819.078
#
#       Gender_Female  Gender_Male
# ...

# %%
df.Accepted.value_counts()
# Out:
# 0    6078
# 1    3422
# Name: Accepted, dtype: int64

# %%
df_new = df.drop_duplicates()

# %%
df_new.Accepted.value_counts()
# Out:
# 0    6078
# 1    3422
# Name: Accepted, dtype: int64

# %%
df_new
# Out:
#       CreditScore  Age  Tenure  NumOfProducts  Accepted  New_Estimated_Salary  \
# 0             619   42       2              1         0             10134.888
# 1             608   41       1              1         0             11254.258
# 2             502   42       8              3         0             11393.157
# 3             699   39       1              2         1              9382.663
# 4             850   43       2              1         1              7908.410
# ...           ...  ...     ...            ...       ...                   ...
# 9995          771   39       5              2         1              9627.064
# 9996          516   35      10              1         0             10169.977
# 9997          709   36       7              1         0              4208.558
# 9998          772   42       3              2         1              9288.852
# 9999          792   28       4              1         0              3819.078
#
#       Gender_Female  Gender_Male
# ...

# %%
df_new.drop(columns=['Gender_Female','Gender_Male'], inplace=True)

# %%
X=df_new.drop(columns=['Accepted'])
y=df_new['Accepted']

# %%
X
# Out:
#       CreditScore  Age  Tenure  NumOfProducts  New_Estimated_Salary
# 0             619   42       2              1             10134.888
# 1             608   41       1              1             11254.258
# 2             502   42       8              3             11393.157
# 3             699   39       1              2              9382.663
# 4             850   43       2              1              7908.410
# ...           ...  ...     ...            ...                   ...
# 9995          771   39       5              2              9627.064
# 9996          516   35      10              1             10169.977
# 9997          709   36       7              1              4208.558
# 9998          772   42       3              2              9288.852
# 9999          792   28       4              1              3819.078
#
# [9500 rows x 5 columns]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=3)

# %%
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler()
sc = sc.fit(X)
X_train=sc.transform(X_train)
X_test=sc.transform(X_test)

# %%
X_train
# Out:
# array([[0.368     , 0.45945946, 0.1       , 0.66666667, 0.4953287 ],
#        [0.64      , 0.17567568, 0.9       , 0.        , 0.34922106],
#        [0.624     , 0.35135135, 0.8       , 0.33333333, 0.87021195],
#        ...,
#        [0.8       , 0.22972973, 0.3       , 0.        , 0.95544294],
#        [0.398     , 0.27027027, 0.8       , 0.        , 0.77621631],
#        [0.414     , 0.32432432, 0.4       , 0.33333333, 0.40385276]])

# %%
X_test
# Out:
# array([[0.384     , 0.09459459, 0.8       , 0.        , 0.23413366],
#        [0.812     , 0.24324324, 0.2       , 0.        , 0.84247984],
#        [0.526     , 0.2972973 , 0.7       , 0.        , 0.96485233],
#        ...,
#        [0.574     , 0.2027027 , 0.5       , 0.33333333, 0.68420102],
#        [0.328     , 0.36486486, 0.3       , 0.        , 0.7655107 ],
#        [0.898     , 0.45945946, 0.4       , 0.        , 0.41668046]])

# %%
X
# Out:
#       CreditScore  Age  Tenure  NumOfProducts  New_Estimated_Salary
# 0             619   42       2              1             10134.888
# 1             608   41       1              1             11254.258
# 2             502   42       8              3             11393.157
# 3             699   39       1              2              9382.663
# 4             850   43       2              1              7908.410
# ...           ...  ...     ...            ...                   ...
# 9995          771   39       5              2              9627.064
# 9996          516   35      10              1             10169.977
# 9997          709   36       7              1              4208.558
# 9998          772   42       3              2              9288.852
# 9999          792   28       4              1              3819.078
#
# [9500 rows x 5 columns]

# %%
y
# Out:
# 0       0
# 1       0
# 2       0
# 3       1
# 4       1
#        ..
# 9995    1
# 9996    0
# 9997    0
# 9998    1
# 9999    0
# Name: Accepted, Length: 9500, dtype: int64

# %%
import tensorflow 
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

# %%
# initializing the ANN model
classifier=Sequential()

# %%
# classifier.add(Dense(6, activation = 'relu',input_dim=10))
classifier.add(Dense(6, activation = 'relu',input_dim=5))
classifier.add(Dense(6,activation='relu'))
classifier.add(Dense(1,activation='sigmoid'))

# %%
classifier.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
classifier.summary()
# Out:
# Model: "sequential_27"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_84 (Dense)            (None, 6)                 36
#
#  dense_85 (Dense)            (None, 6)                 42
#
#  dense_86 (Dense)            (None, 1)                 7
#
# ...
# Total params: 85
# Trainable params: 85
# Non-trainable params: 0
# _________________________________________________________________

# %%
ACCURACY_THRESHOLD = 0.99

# %%
# Implement callback function to stop training
# when accuracy reaches e.g. ACCURACY_THRESHOLD = 0.95
class myCallback(keras.callbacks.Callback): 
    def on_epoch_end(self, epoch, logs={}): 
        if(logs.get('accuracy') > ACCURACY_THRESHOLD):   
            print("\nReached %2.2f%% accuracy, so stopping training!!" %(ACCURACY_THRESHOLD*100))   
            self.model.stop_training = True

# %%
callbacks = myCallback()

# %%
# batch_size = 1
# epochs = 200
# shuffle = False


history = classifier.fit(X_train,y_train,batch_size=10,epochs=100,verbose=1,callbacks = [callbacks],validation_split=0.25)
# Out:
# Epoch 1/100
# 535/535 [==============================] - 4s 5ms/step - loss: 0.6296 - accuracy: 0.6337 - val_loss: 0.5753 - val_accuracy: 0.6308
# Epoch 2/100
# 535/535 [==============================] - 2s 5ms/step - loss: 0.5095 - accuracy: 0.6919 - val_loss: 0.4461 - val_accuracy: 0.8339
# Epoch 3/100
# 535/535 [==============================] - 3s 5ms/step - loss: 0.3934 - accuracy: 0.8551 - val_loss: 0.3581 - val_accuracy: 0.8793
# Epoch 4/100
# 535/535 [==============================] - 2s 4ms/step - loss: 0.3251 - accuracy: 0.8959 - val_loss: 0.3009 - val_accuracy: 0.9141
# Epoch 5/100
# 535/535 [==============================] - 3s 5ms/step - loss: 0.2781 - accuracy: 0.9162 - val_loss: 0.2624 - val_accuracy: 0.9276
# Epoch 6/100
# 535/535 [==============================] - 2s 5ms/step - loss: 0.2448 - accuracy: 0.9283 - val_loss: 0.2352 - val_accuracy: 0.9343
# Epoch 7/100
# ...

# %%
# list all data in history

print(history.history.keys())
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
import joblib

joblib.dump(classifier, 'classifier_isuke.pkl')
# Out:
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\dense_1
# ......vars
# .........0
# .........1
# ...layers\dense_2
# ......vars
# .........0
# .........1
# ...metrics\mean
# ......vars
# .........0
# .........1
# ...metrics\mean_metric_wrapper
# ......vars
# .........0
# .........1
# ...optimizer
# ......vars
# .........0
# .........1
# .........10
# .........11
# .........12
# .........2
# .........3
# .........4
# .........5
# .........6
# .........7
# .........8
# .........9
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# config.json                                    2023-06-09 05:57:14         1830
# metadata.json                                  2023-06-09 05:57:14           64
# variables.h5                                   2023-06-09 05:57:14        23120
# ['classifier_isuke.pkl']

# %%
from flask import Flask, request, jsonify
import sys
from sklearn.preprocessing import MinMaxScaler

sc = MinMaxScaler()
sc = sc.fit(X)

app = Flask(__name__)

@app.route('/predict', methods=['POST'])
def predict():
    try:
        CreditScore = int(request.form.get('CreditScore'))
        Tenure = int(request.form.get('Tenure'))
        NumOfProducts = int(request.form.get('NumOfProducts'))
        Age_category = int(request.form.get('Age'))
        New_Estimated_Salary = float(request.form.get('Estimated_Salary'))
#         Gender = request.form.get('Gender')
        
#         data = [CreditScore,Tenure,NumOfProducts,,New_Estimated_Salary,Gender]
#         print(data)
        
#         if(CreditScore < 652):
#             CreditScore = 1
#         elif(CreditScore < 750):
#             CreditScore = 2
#         elif(CreditScore > 750):
#             CreditScore = 3
            
#         if(Age_category < 30):
#             Age_category = 1
#         elif(Age_category < 54):
#             Age_category = 2
#         elif(Age_category > 54):
#             Age_category = 0
            
#         if(New_Estimated_Salary < (5000)):
#             New_Estimated_Salary = 1
#         elif(New_Estimated_Salary < (15000)):
#             New_Estimated_Salary = 2
#         elif(New_Estimated_Salary > (15000)):
#             New_Estimated_Salary = 3
        
        
#         if Gender.strip():
#             if Gender == 'male':
#                 Gender_Female = 0
#                 Gender_Male = 1 
#             elif Gender == 'female':
#                 Gender_Female = 1
#                 Gender_Male = 0
#         else:
#             return jsonify({'Error': ["There's No valid input in line."]})

        data = [CreditScore,Age_category,Tenure,NumOfProducts,New_Estimated_Salary]
        print(data)
    
      
        data_baru=sc.transform([data])
          
        print(data_baru)
        

        classifier = joblib.load('classifier_isuke.pkl')
        prediction = classifier.predict([data_baru])
        
        prediksi = 1
        if(prediction[0] < 0.5):
            prediksi = 0
        
        return jsonify({'success':200,'status': prediksi,'confidence':str(prediction[0][0])})
    except ValueError:
        print("There's No Valid input in line.")
        return jsonify({'success':0,'Error': "There's No valid input in line."})
    except:
        print("Unexpected error:", sys.exc_info()[0])
        return jsonify({'success':0,'Error': "Unexpected error."})
        raise 
    



if __name__ == '__main__':
     app.run(host="127.0.0.1",port="5000")
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# [700, 35, 2, 1, 10000.0]
# [[0.7        0.22972973 0.2        0.         0.47410509]]
# Keras model archive loading:
# File Name                                             Modified             Size
# config.json                                    2023-06-09 05:57:14         1830
# metadata.json                                  2023-06-09 05:57:14           64
# variables.h5                                   2023-06-09 05:57:14        23120
# D:\anaconda\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers\dense
# ...

# %%
df_new
# Out:
#      CreditScore  Tenure  NumOfProducts Age_category New_Estimated_Salary  \
# 0              1       2              1            2                    2
# 1              1       1              1            2                    2
# 2              1       8              3            2                    2
# 3              2       1              2            2                    2
# 4              3       2              1            2                    2
# ...          ...     ...            ...          ...                  ...
# 9747           1       5              3            0                    3
# 9800           3       3              3            2                    1
# 9877           1       3              3            2                    1
# 9888           1      10              1            1                    3
# 9894           1       6              2            0                    1
#
#       New_Accepted  Gender_Female  Gender_Male
# ...

# %%
test_pred = classifier.predict([[0.898     , 0.45945946, 0.4       , 0.        , 0.41668046]])
test_pred
# Out:
# 1/1 [==============================] - 0s 57ms/step
# array([[0.8209441]], dtype=float32)

# %%
X
# Out:
#      CreditScore  Tenure  NumOfProducts Age_category New_Estimated_Salary  \
# 0              1       2              1            2                    2
# 1              1       1              1            2                    2
# 2              1       8              3            2                    2
# 3              2       1              2            2                    2
# 4              3       2              1            2                    2
# ...          ...     ...            ...          ...                  ...
# 9747           1       5              3            0                    3
# 9800           3       3              3            2                    1
# 9877           1       3              3            2                    1
# 9888           1      10              1            1                    3
# 9894           1       6              2            0                    1
#
#       Gender_Female  Gender_Male
# 0                 1            0
# ...

# %%
X[:10].values
# Out:
# array([[1, 2, 1, 2, 2, 1, 0],
#        [1, 1, 1, 2, 2, 1, 0],
#        [1, 8, 3, 2, 2, 1, 0],
#        [2, 1, 2, 2, 2, 1, 0],
#        [3, 2, 1, 2, 2, 1, 0],
#        [1, 8, 2, 2, 2, 0, 1],
#        [3, 7, 2, 2, 1, 0, 1],
#        [1, 4, 4, 1, 2, 1, 0],
#        [1, 4, 2, 2, 2, 0, 1],
#        [2, 2, 1, 1, 2, 0, 1]], dtype=int64)

# %%
y[:10]
# Out:
# 0    0
# 1    0
# 2    0
# 3    1
# 4    1
# 5    0
# 6    0
# 7    0
# 8    0
# 9    1
# Name: New_Accepted, dtype: int64

# %%
test_pred = classifier.predict([[2, 1, 2, 2, 2, 1, 0]])
test_pred
# Out:
# 1/1 [==============================] - 0s 56ms/step
# array([[1.7615667e-31]], dtype=float32)
